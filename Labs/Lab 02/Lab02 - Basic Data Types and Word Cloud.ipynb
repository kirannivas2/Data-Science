# %% [markdown]
# # Exercise 02: Word Clouding using Basic Data Types
#
# In this exercise you are going to make a Word Cloud: a collage that representes how often a word is used in a body of text by how large the word appears in the image.  With the exception of the code included in this notebook skelenton, you should only need to use the basic Python data types (strings, lists, sets, and dictionaries), if-statements, and for-loops to complete this project.
#
#
# ## Overview
# Input: the text of *Frankenstein*
#
# Final Data Output: A dictionary with the keys being uncommon words from the book paired to the frequency of the word
#
# Final Visual: A word cloud of these uncommon words
#
#
# ## Objectives
# + Learn to install packages using Anaconda Navigator
# + Explore using a Python notebook
# + Demonstrate your undertanding of Python built-in data types: sets, lists, dictionaries, strings
#
#
# ## Before you begin
# Make sure you have installed the wordcloud package from conda-forge.
#
# **Remember to execute the cells in order to run the code in them.  If you want to start over, you can restart the Kernel from the menu**
#
# **Also add cells and explore the output along the way.  Development and analysis is an iterative process.**

# %%
# Here are our package imports
# We'll discuss them later

# Needed for our HTTP requests
import urllib  

# Needed to do the plotting
from matplotlib import pyplot as plt  

# I want to make the figure larger
plt.rcParams['figure.figsize'] = (40,30) 

# Our third-party WordCloud library
from wordcloud import WordCloud

# %% [markdown]
# ## Part 0: Downloading a book
#
# For this exercise we are going to download the book *Frankenstein* by Mary Shelly. The cell below does this for you.  Run this cell to download the book as a single string called `book_text`.

# %%
import urllib
url = 'http://www.cse.msu.edu/~ruppmatt/itm891/frankenstein.txt'
with urllib.request.urlopen(url) as response:
    book_text = response.read().decode('utf-8')  # This is a string that contains the book

# %% [markdown]
# ## Part 1: Preprocessing the text of the book
#
# ### Overview
#
# Input: A string containing the text of the book (you should have executed the code cells above before you execute any cells below)
#
# Output: A string of the text of the book that contains capitalized words and spaces *only*.
#
#
# ### Description
#
# The string `book_text` created in the Part 0 contains numbers, punctuation, and other characters that we don't want to include in our final word cloud.  Before we go any further, let's remove those characters.  While we're at it, let's rid ourselves of lowercase letters so that the words at beginning of sentences and proper nouns aren't counted differently than words that are all lowercase.
#
# Consider the following questions when solving this sub-problem:
# * We want to handle just capital letters.  Is there a way to make a new string that contains an uppercase version of the `book_text` string?  (Use Google!)
#     + Once we've converted the string to uppercase, we will only work with that string from now on, not the original that contained both upper and lowercase letters.
# * How do you know what characters are in the text of the book?
#     + Which data structure deals with keeping a collection of unique objects?
#     + What happens when you create this data structure with a string as the only parameter?  Play with that idea in the notebook.
#     + Create an collection (list, set, dict pick one) that contains the unqiue characters in the capitalized version of the text.
# * If you have a collection of unique characters in the book and a collection of English capitalized letters and space, how would you find the characters you would like to replace?
#     + Look at the documentation for this collection datatype that contains unique elements.  Is there a way to subtract one collection from another?  The result should give you all the characters you need to replace.
# * Once you've gotten a collection of characters you want to remove, how do you remove them?
#     + Try replacing them with spaces.  Is there a method you can call on a string to do this?  (Google it!)
#     + Make a loop that will iterate over the characters you would like to remove and replace them with spaces in the uppercase book string.  This will be the output for this part of the exercise.
#
# To answer the questions above, consider the strengths of the basic data types we covered today and the methods you may call on them.  Google the documentation!

# %%
# Place your solution to the subproblem here

upper_book_text = book_text.upper()
book_characters = set(book_text)
chars_to_keep = set(list('ABCDEFGHIJKLMNOPQRSTUVWXYZ'))
replace_book_characters = book_characters - chars_to_keep
for char in replace_book_characters:
    upper_book_text = upper_book_text.replace(char, ' ')

# %% [markdown]
# ## Part 2: Creating collection of unique words in the book
#
# ### Overview
#
# Input: A string containing the capitalized text of the book and whitespace
#
# Output: A collection of unique words in the book
#
#
# ### Description
#
# In the next section we are going to remove common words from the text.  Before we do that, we need to know what words are used in the book.
#
# + We're working on the uppercase string version of the book with non-English and non-space characters removed.
# + Is there some way to split the string into words?  Google it.
# + Once we have a collection of all words in the book, is there a way to convert that to a collection of *unique* words in the book?  What data structure would you use?  What happens if you initialize that data structure with a list of words?

# %%
# Place your solution to the subproblem here
words = upper_book_text.split () 
unique_words=set(words)
print(unique_words)
# Out:
# {'FEET', 'TWICE', 'SEDULOUS', 'AMELIORATE', 'BRIGHTEST', 'WAND', 'BASED', 'DIRGE', 'INTERPRETER', 'PATRIARCHAL', 'POSSESSIONS', 'UNPLASTERED', 'HOUSE', 'CATARACT', 'FROGS', 'DIVERTED', 'CONVEYED', 'ATTAINED', 'SEXES', 'RENDS', 'TALES', 'NATIONS', 'BIRD', 'SEPULCHRE', 'DOTH', 'ADDUCED', 'WRITING', 'INASMUCH', 'DERIVE', 'SENSES', 'CALL', 'ACCOUNT', 'BEGINNING', 'MASTER', 'SOLITUDES', 'VICAR', 'PRIZE', 'INFIRMITIES', 'RANKED', 'SPLINTERED', 'WOES', 'MELANCHOLY', 'RENEWED', 'BUSIED', 'INROADS', 'MAIN', 'ALSO', 'REQUEST', 'ROCK', 'SONG', 'OCTOBER', 'AROUSED', 'BROTHER', 'GOVERNING', 'POSSESSED', 'CONFIDE', 'CROWN', 'SHATTERED', 'ESCAPE', 'SKIES', 'VILLAGERS', 'CONDUCT', 'CLINGING', 'POWER', 'REMAINS', 'SHUDDER', 'PURSUITS', 'EARLIEST', 'MONUMENT', 'CONVENIENTLY', 'MILANESE', 'SPARKLED', 'SEEK', 'NATURAL', 'HORRORS', 'PURPOSED', 'PRINCIPLES', 'WREATHS', 'UTTERED', 'ATLANTIC', 'FORBID', 'UNCONTROLLABLE', 'MERCHANTMAN', 'DISCONTENTED', 'SOCIAL', 'INTERPRET', 'SCION', 'GENIUS', 'ELASTICITY', 'FARE', 'OUTHOUSE', 'CONSTERNATION', 'WRITE', 'WOUNDS', 'PLAITED', 'CHAMOUNIX', 'MOURN', 'FEBRUARY', 'UNGRATITUDE', 'FELIX', 'PROBLEM', 'THREATS', 'DORMANT', 'CLOSER', 'ATTENDS', 'DEFEAT', 'WIND', 'SKELETON', 'ALLEGING', 'SUMMIT', 'TOOK', 'DESERVED', 'GRAVES', 'PRECEPTORS', 'UNFITTED', 'RETRIBUTION', 'DIVINEST', 'OVERLOOK', 'FRANCE', 'WEEPING', 'ELECTRONIC', 'PERCEPTIONS', 'FASHIONED', 'PROGRESS', 'THROWN', 'DISASTER', 'DIFFERING', 'RIVERS', 'ISLANDS', 'CARPETED', 'FRENCHWOMAN', 'WAKEFIELD', 'INSTIGATED', 'HANDKERCHIEF', 'SCHOOLBOYS', 'GRATIFYING', 'TRACK', 'FOOLISH', 'FOURTEEN', 'PASSED', 'DANGERS', 'ASSURED', 'PROPHESIED', 'NOVELTY', 'EXTORT', 'RELATES', 'KINDS', 'AGAIN', 'BOAST', 'FEAR', 'JOYS', 'REVERSES', 'POSTERITY', 'INESTIMABLE', 'SURMOUNTING', 'THESE', 'ARREST', 'ALARM', 'SALT', 'VIGOROUS', 'OCEAN', 'BIND', 'CANVASSED', 'SEPTEMBER', 'DEGENERATING', 'PICKED', 'IDLE', 'ARIOSTO', 'FAMILY', 'PUBLIC', 'SMOTHERED', 'ALIVE', 'CIRCUMSTANCES', 'HOVERS', 'INHERITANCE', 'ADMIRE', 'STAYED', 'GLORIOUS', 'WOE', 'EXTINCT', 'MOUNTAIN', 'HORROR', 'UNDERSTOOD', 'CHARMING', 'EMBARKS', 'INTOLERABLE', 'DENOUNCE', 'PROGNOSTICATE', 'THREATENED', 'MISFORTUNE', 'LOUIS', 'RESUMED', 'TURNKEYS', 'PREPOSSESS', 'STUDENT', 'ACQUIRED', 'HAUNT', 'STIFLE', 'COMPLACENCY', 'DILIGENCE', 'SHADOWS', 'RESPECT', 'SUMMER', 'HOVERED', 'SKIMS', 'ENTIRE', 'BONES', 'SUPPRESSED', 'CHARMED', 'SUCCESSIVE', 'TRASH', 'QUITE', 'EFFORTS', 'PRODUCTIONS', 'ACME', 'IMPRECATIONS', 'REMORSE', 'UNPRACTISED', 'B', 'STEP', 'TORRENTS', 'ATTRACTED', 'LOW', 'WEIGHS', 'HUNT', 'UNLAWFUL', 'BARREN', 'ECHOED', 'PRONOUNCING', 'SHORE', 'OUTWARD', 'FUNDRAISING', 'REVERIE', 'PENETRATED', 'JUSTIFIED', 'TRANCE', 'INDEPENDENCE', 'ACCOMPLISHMENTS', 'KNEEL', 'PARTICULARS', 'DISTRIBUTING', 'LANGUAGE', 'FRANKENSTEIN', 'ARCH', 'TAPPED', 'SLIGHT', 'DESPONDENCY', 'GLOOM', 'EMBLEM', 'GUILT', 'THE', 'EIGHTEENTH', 'COLLEGES', 'WORSE', 'EXTRACT', 'NARRATED', 'INSECT', 'VILLAGE', 'VISITOR', 'FATALLY', 'SCHOOL', 'RETAINS', 'ATTRACTIVE', 'CAREFULLY', 'PRECIPICE', 'CONSTRUCTED', 'COARSER', 'WEDDING', 'VARIEGATED', 'THICKLY', 'ORDERED', 'EVE', 'VEIL', 'SURE', 'JANUARY', 'WORLDLY', 'ARGUE', 'PERTURBED', 'UNVISITED', 'CARRIED', 'CHANGE', 'SHUNNED', 'SIMPLER', 'KILL', 'SWISS', 'CHOICE', 'SERIOUS', 'KEPT', 'AFFLICTED', 'WITHDRAWN', 'SPOTS', 'CONSIDERATION', 'APART', 'BELIEF', 'INTRICACIES', 'STOP', 'VICTIM', 'REPEATING', 'CONFUSION', 'DISASTROUS', 'PAINED', 'CHOICEST', 'BUDDING', 'SHAMEFULLY', 'CAUSES', 'MOVING', 'RAPID', 'INFINITELY', 'TONED', 'AFFIRMATIVE', 'RAVENOUS', 'COMMUNION', 'COMPARATIVE', 'PATTERED', 'STUFF', 'SUNSHINE', 'INQUIRING', 'INTUITIVE', 'CHARITY', 'MULTIFARIOUS', 'DESPITE', 'EACH', 'DETAIN', 'RATE', 'ADAM', 'EITHER', 'OPAQUE', 'CONJECTURES', 'CONCERNED', 'HADST', 'COMPLAINED', 'COASTING', 'SUNLIGHT', 'INTIMIDATED', 'BESIEGED', 'BEAT', 'CREW', 'SHONE', 'UNFOLDED', 'TINTERN', 'STATURE', 'CABINETS', 'LESSON', 'GRADES', 'HARD', 'HOPELESS', 'IMPLEMENTS', 'FAITHFUL', 'CHRISTY', 'ASPIRED', 'INSTRUCTORS', 'CRAMPED', 'TIM ...

# %% [markdown]
# ## Part 3: Getting common words
#
# ### Overview
#
# Input: From this notebook, nothing.
#
# Output: We want a unique collection of common words to use in the next step to remove them from the text.
#
#
# ### Description
#
# Examine the code in the Part 0 section.  There is a file that contains common words located at the following URL:
#     http://www.cse.msu.edu/~ruppmatt/itm891/common_words.txt
#
# 1. Copy and paste the code from Part 0 to create a new string of common words.
# 2. Make a collection of the unique words from the string of common words.
#
# Note: Examine what that file contains.  Is it in the right format for what we need?  Is it upper or lowercase?  Examine the output of each step in the process for solving this step as you go along.

# %%
# Copy code from Part 0 here and extend it as described above
import urllib
url2 = 'http://www.cse.msu.edu/~ruppmatt/itm891/common_words.txt'
with urllib.request.urlopen(url2) as response2:
    common_words_0 = response2.read().decode('utf-8')
    upper_common_words=common_words_0.upper()
    upper_common_words_1=upper_common_words.split () 
    unique_upper_common_words_1=set(upper_common_words_1)
    print(unique_upper_common_words_1)
# Out:
# {'TOP', 'OFTEN', 'FEET', 'CONSIDER', 'THOUSAND', 'SPEECH', 'DIE', 'DRY', 'SUBJECT', 'PER', 'DOUBLE', 'APPEAR', 'YOUNG', 'BLACK', 'SPEED', 'PLANET', 'MEAT', 'STAR', 'SPEAK', 'SEPARATE', 'DRIVE', 'WALL', 'PULL', 'CIRCLE', 'STATE', 'THOSE', 'BAT', 'GATHER', 'SHOP', 'SEAT', 'WAY', 'LIGHT', 'LOVE', 'CLAIM', 'WIN', 'SUIT', 'SPEND', 'DRESS', 'READY', 'SCALE', 'DOG', 'ROAD', 'COST', 'FRUIT', 'LIVE', 'RAISE', 'CHAIR', 'ARE', 'HOUSE', 'COOK', 'WING', 'PROPER', 'SENT', 'THEIR', 'NEW', 'FAMOUS', 'BORN', 'STREAM', 'MOST', 'BIRD', 'GO', 'COLONY', 'WE', 'SHORT', 'BRING', 'CONTINUE', 'ALL', 'DESIGN', 'LEFT', 'OPPOSITE', 'LADY', 'STRETCH', 'EDGE', 'NINE', 'SUN', 'SUGAR', 'CALL', 'THANK', 'ANTI', 'NORTH', 'PLUS', 'TRUCK', 'OFFICE', 'SOUTH', 'ABLE', 'MASTER', 'LAUGH', 'BOARD', 'FRESH', 'THROW', 'EVENING', 'PAIR', 'MATTER', 'FROM', 'SHOUT', 'OVER', 'VALLEY', 'ELSE', 'TEACH', 'SMALL', 'BUY', 'EXAMPLE', 'TEMPERATURE', 'MEAN', 'PATH', 'ALWAYS', 'NEAR', 'PUT', 'CENTURY', 'CONSIDERING', 'COLOR', 'HE', 'SON', 'LOCATE', 'CONTINENT', 'SPOT', 'LOUD', 'AMONG', 'MAIN', 'ALSO', 'PRINT', 'CELL', 'LAND', 'FORCE', 'KEEP', 'SCIENCE', 'TIME', 'ROCK', 'ABOVE', 'DESCRIBE', 'OXYGEN', 'BEFORE', 'SONG', 'PROTECT', 'PLURAL', 'COUNTRY', 'SIDE', 'FACT', 'STAY', 'BROTHER', 'RESULT', 'GUESS', 'RANGE', 'SOLUTION', 'IN', 'HIM', 'RIDE', 'COAT', 'TEETH', 'SUPPLY', 'RACE', 'CAME', 'UPON', 'ENOUGH', 'GUN', 'DRINK', 'CAPITAL', 'REPRESENT', 'RICH', 'WHOLE', 'GAS', 'BOY', 'WILL', 'KEY', 'POWER', 'CHOOSE', 'CONDITION', 'FAT', 'HIGH', 'REMEMBER', 'TOWARDS', 'HOLD', 'BOTH', 'ROSE', 'GUIDE', 'CENT', 'FELL', 'CAR', 'FREE', 'ANSWER', 'HEAT', 'WITHOUT', 'SELECT', 'MAY', 'SURFACE', 'MAP', 'DICTIONARY', 'NIGHT', 'BLOW', 'THIN', 'DOOR', 'CHICK', 'NATURAL', 'COUNT', 'HOT', 'EVEN', 'ART', 'WIRE', 'SHARP', 'PRETTY', 'TWO', 'MARKET', 'LIQUID', 'LED', 'CENTER', 'COULD', 'DEVELOP', 'PHRASE', 'PLEASE', 'BEING', 'OWN', 'DOLLAR', 'SHALL', 'TUBE', 'MIND', 'GAME', 'INSTRUMENT', 'AGE', 'BREAK', 'CHARACTER', 'NOTE', 'LIST', 'MOLECULE', 'NATURE', 'MINUS', 'SOFT', 'LIE', 'REGARDING', 'CONTROL', 'WRITE', 'PIECE', 'GAVE', 'FRONT', 'SIZE', 'THUS', 'DROP', 'BOX', 'COLLECT', 'WILD', 'HOLE', 'BY', 'HAD', 'PROBLEM', 'IS', 'THICK', 'DANGER', 'WOMEN', 'WIND', 'MILK', 'HAPPY', 'SEND', 'NUMBER', 'ONTO', 'CLOTHE', 'QUICK', 'RULE', 'FIRST', 'USE', 'TABLE', 'AFTER', 'PLAY', 'TOOK', 'WHETHER', 'RAN', 'SILENT', 'DOCTOR', 'DEATH', 'HELD', 'FIND', 'REST', 'WEIGHT', 'NOTHING', 'GLAD', 'EVER', 'EXERCISE', 'LEARN', 'MONEY', 'BELIEVE', 'ROLL', 'APPLE', 'EXCITE', 'FAST', 'DOES', 'OUT', 'MAKE', 'THAN', 'STOOD', 'DIVIDE', 'OFFER', 'ROUND', 'PRESS', 'SUBSTANCE', 'OUR', 'AMID', 'FIGHT', 'SKIN', 'YELLOW', 'DEGREE', 'SIGN', 'HAND', 'ANIMAL', 'AREA', 'STRONG', 'MOTION', 'DEAR', 'FIVE', 'TOGETHER', 'MARK', 'PICK', 'JOB', 'SEVEN', 'SELL', 'BEAUTY', 'INCH', 'BEYOND', 'ICE', 'OTHER', 'PAY', 'CHANCE', 'GRASS', 'TRACK', 'SYLLABLE', 'MILLION', 'DECIDE', 'SPREAD', 'PROPERTY', 'PARTICULAR', 'PROJECT', 'CLIMB', 'NAME', 'ABOUT', 'DISCUSS', 'GET', 'SHOE', 'BACK', 'AN', 'AGAIN', 'MINE', 'HUMAN', 'SAT', 'WENT', 'FEAR', 'KNEW', 'ACROSS', 'HAVE', 'RING', 'FOLLOW', 'SISTER', 'LETTER', 'INCLUDE', 'CASE', 'THESE', 'WONDER', 'SAID', 'CHECK', 'DIFFER', 'GIRL', 'NOON', 'YEAR', 'SAND', 'SLAVE', 'KING', 'ONCE', 'SALT', 'BE', 'REGION', 'TEN', 'SLOW', 'RECORD', 'EARLY', 'OCEAN', 'HAS', 'OBSERVE', 'RADIO', 'STAND', 'CLASS', 'HOPE', 'ENTER', 'FAMILY', 'TOTAL', 'ESPECIALLY', 'FEEL', 'CORRECT', 'LARGE', 'SOME', 'SOLDIER', 'SO', 'ANGER', 'CURRENT', 'YARD', 'TEST', 'SNOW', 'INTEREST', 'LONG', 'HER', 'LIFT', 'PARENT', 'MOUNTAIN', 'TO', 'SAVE', 'WITHIN', 'CONSONANT', 'BEAR', 'BUT', 'IRON', 'VIEW', 'STRING', 'AS', 'BELL', 'LAW', 'GREAT', 'PREPARE', 'HAIR', 'COOL', 'DARK', 'AFRAID', 'NOUN', 'YES', 'WARM', 'MATCH', 'SEGMENT', 'FOUND', 'STUDENT', 'PLAN', 'SEASON', 'SOLVE', 'NECK', 'LITTLE', 'EAT', 'SIX', 'ENGINE', 'ATOM', 'MACHINE', 'WOMAN', 'TIE', 'SEA', 'LAY', 'HEART', 'SUCH', 'SUMMER', 'KNOW', 'SMELL', 'MINUTE', 'TOUCH', 'VERSUS', 'EXACT', 'SHINE', 'MUST', 'WALK', 'UNIT ...

# %% [markdown]
# ## Part 4: Removing common words from the text
#
# ### Overview
#
# Input:
# * The collection of unique words in the text from Part 2
# * The collection of common words downloaded in Part 3
#
# Output: A collection of words in the book that aren't common
#
#
# ### Description
#
# Using the unique collection of words Part 2 (in the book) and Part 3 (common words overall) you should be able to remove the common words from the collection of unique words in the book.
#
# + If both of these are the same data type that represents a collection of unique objects, what operator would you use to get just the uncommon words in the book?

# %%
# Place your solution to the subproblem here
remove_common_words=unique_words-unique_upper_common_words_1
print (remove_common_words)
#print(len(unique_words))
#print(len(unique_upper_common_words_1))
#print(len(remove_common_words))
# Out:
# {'TWICE', 'EXCLAIMED', 'COMMIT', 'SEDULOUS', 'LOCALITIES', 'AMELIORATE', 'CROSSED', 'PASSIONATELY', 'BRIGHTEST', 'WAND', 'BASED', 'BELONGING', 'STREAMS', 'DIRGE', 'INTERPRETER', 'PATRIARCHAL', 'MUSTY', 'POSSESSIONS', 'ACUTENESS', 'POSSESSING', 'UNPLASTERED', 'REFLECTING', 'PERSEVERING', 'CATARACT', 'FROGS', 'DIVERTED', 'CONVEYED', 'LOOKING', 'ATTAINED', 'SEXES', 'RENDS', 'AWAKEN', 'MUSCLE', 'GRIEF', 'RENDERING', 'TALES', 'UNSEEN', 'NATIONS', 'SEPULCHRE', 'SAD', 'CONSEQUENCES', 'GUILTLESSNESS', 'DOTH', 'ADDUCED', 'WRITING', 'INASMUCH', 'DERIVE', 'RASHLY', 'SENSES', 'INTOXICATING', 'ACCOUNT', 'PREPARATION', 'BEGINNING', 'GATES', 'VEILED', 'SOLITUDES', 'VICAR', 'PRIZE', 'INFIRMITIES', 'REPENTANCE', 'RANKED', 'MARTYRS', 'SPLINTERED', 'GRASP', 'WOES', 'CALCULATE', 'AWFUL', 'EVILS', 'MELANCHOLY', 'RENEWED', 'BUSIED', 'INROADS', 'COWARD', 'YOURS', 'REQUEST', 'EPOCH', 'GOVERNMENTS', 'ALMOST', 'FOUNDED', 'OCTOBER', 'AROUSED', 'DECISIVE', 'ACCEPT', 'TOWERS', 'FAMILIES', 'GOVERNING', 'STRANGELY', 'CONCEAL', 'POSSESSED', 'DEARER', 'CONVERT', 'MODEST', 'FLORINS', 'PROFOUND', 'CONFIDE', 'CROWN', 'SHATTERED', 'ESCAPE', 'SKIES', 'VILLAGERS', 'TORPOR', 'DETESTABLE', 'PERFORMED', 'CONDUCT', 'DARKENED', 'CLINGING', 'ASSEMBLANCE', 'LUXURIANT', 'EDUCATIONAL', 'AWARE', 'REMAINS', 'SHUDDER', 'CHAINS', 'REMEMBRANCERS', 'EXTRACTING', 'BLOOM', 'PURSUITS', 'EARLIEST', 'MONUMENT', 'DANGEROUSLY', 'CONVENIENTLY', 'MILANESE', 'ADORNED', 'RESIDENTS', 'SPARKLED', 'DIET', 'INDELIBLY', 'EXPLOIT', 'SEEK', 'HORRORS', 'PURPOSED', 'PRINCIPLES', 'WREATHS', 'WHISPER', 'UTTERED', 'WILDEST', 'ATLANTIC', 'WONDROUSLY', 'FORBID', 'UNCONTROLLABLE', 'DEATHBED', 'EXPLORE', 'LINGERED', 'CAPITULATED', 'ARISE', 'WONDERS', 'BELOVED', 'ARABIC', 'MERCHANTMAN', 'ABSOLUTION', 'DISCONTENTED', 'SOCIAL', 'INTERPRET', 'SHOCK', 'ASSERTION', 'CHARMS', 'OBEYING', 'SCION', 'AVENGE', 'CUMBERLAND', 'GENIUS', 'ELASTICITY', 'FARE', 'OUTHOUSE', 'URI', 'CONSTERNATION', 'WOUNDS', 'GLENS', 'PLAITED', 'HOPED', 'PEACEABLY', 'CHAMOUNIX', 'MOURN', 'FLAGRANT', 'ACCIDENTALLY', 'FEBRUARY', 'JOHN', 'FURNISHED', 'RUBBED', 'UNGRATITUDE', 'FELIX', 'PREJUDICE', 'MIXTURE', 'THREATS', 'GREATER', 'FERVENTLY', 'VESSEL', 'DORMANT', 'CLOSER', 'SYSTEMS', 'ENORMITY', 'ATTENDS', 'DEFEAT', 'TRANSPORT', 'SPEAKER', 'THEORY', 'SKELETON', 'SYMMETRY', 'ALLEGING', 'VICTORY', 'SUMMIT', 'DESERVED', 'PRODUCTION', 'GRAVES', 'PRECEPTORS', 'NOUGHT', 'UNFITTED', 'SIMPLEST', 'RETRIBUTION', 'ZEAL', 'DIVINEST', 'INCLUDING', 'INVESTIGATING', 'OVERLOOK', 'FRANCE', 'UNFOLDING', 'VOLUNTARILY', 'WEEPING', 'ELECTRONIC', 'PERCEPTIONS', 'TURKISH', 'TREASURE', 'STARED', 'FASHIONED', 'PROGRESS', 'THROWN', 'DISASTER', 'DIFFERING', 'RIVERS', 'HOVEL', 'ISLANDS', 'CARPETED', 'REFERENCES', 'ASIA', 'FRENCHWOMAN', 'TASK', 'WAKEFIELD', 'UNFORTUNATELY', 'INSTIGATED', 'HANDKERCHIEF', 'QUIETED', 'CITADEL', 'SCHOOLBOYS', 'GRATIFYING', 'FOOLISH', 'HASTY', 'FOURTEEN', 'PASSED', 'DANGERS', 'ASSURED', 'PERFORMS', 'PROPHESIED', 'NOVELTY', 'EXTORT', 'RELATES', 'KINDS', 'REFLECTED', 'STOLE', 'TERRIFICALLY', 'ANNOYING', 'BOAST', 'UNMINGLED', 'WISHED', 'JOYS', 'REVERSES', 'POSTERITY', 'INESTIMABLE', 'OCCUPATIONS', 'SURMOUNTING', 'ONES', 'DEFERRED', 'ARREST', 'ALARM', 'ILLNESS', 'JUTTING', 'FORTUNATE', 'PROBABLY', 'FIRING', 'FIX', 'DISGUISE', 'VIGOROUS', 'BIND', 'CANVASSED', 'WORTHY', 'PERPETRATE', 'SEPTEMBER', 'DEGENERATING', 'SINCERITY', 'GLADNESS', 'SHOWERS', 'PICKED', 'VINEYARDS', 'IDLE', 'ARIOSTO', 'ADMITTANCE', 'HAPPINESS', 'HAGGARD', 'PUBLIC', 'SMOTHERED', 'ALIVE', 'ASSOCIATED', 'HABITATIONS', 'CIRCUMSTANCES', 'FIENDISH', 'HOVERS', 'INHERITANCE', 'ADMIRE', 'BORE', 'PROTECTION', 'STAYED', 'GLORIOUS', 'NAVAL', 'WOE', 'OWE', 'EXTINCT', 'HORROR', 'UNDERSTOOD', 'CHARMING', 'CONSUMPTION', 'LORDS', 'FANGS', 'SENSIBILITY', 'EMBARKS', 'BINDING', 'INTOLERABLE', 'DENOUNCE', 'PROGNOSTICATE', 'THREATENED', 'MISFORTUNE', 'LOUIS', 'RESUMED', 'TURNKEYS', 'BLAME', 'ANGUISH', 'MACHINES', 'CONVULSIVE', 'PREPOSSESS', 'THINE', 'ACQUIRED', 'EMPLOYED', 'HAUNT', 'STIFLE', 'DRESSED',  ...

# %% [markdown]
# ## Part 5: Getting the word frequency of uncommon words from the text
#
# ### Overview
#
# Input:
# * The cleaned book text from Part 1
# * The uncommon and unique words from Part 4
#
# Output:  A dictionary where the keys are the uncommon and unique words in the book and the value is the count of those words.  We also want small-length words removed.
#
# There are a number of things we need to consider:
# + We're going to begin again with the santized book text from Part 1.  We want a collection of words from that santized text, but this time a collection of all words, not just the unique words.
# + We have a unique collection of uncommon words in the book from Part 4.
# + Somehow we need to *iterate* over the list of uncommon words in the book and
#     - count the number of times those words appear
#     - store that count in a manner that associates them with the word
#     - ignore small-length words (we'll say less than 3 characters)
#     - since we need to iterate, we'll have to use a loop
# + Is there a way to count the number of times a word appears in a non-unique collection of words?  (Google it!)
# + We need a data structure to *map* a word to its count.
#     - is there a data structure that does a mapping from a key to a value?
#     - how do you associate a word (key) with its count (value)
#     - (this data structure might be mentioned in the output documentation above)
#
# Imagine that we had a list of words in a variable called `words_in_book` that contains a list of all words in the book.  If we wanted to iterate over it, we could:
#
#     for word in words_in_book:
#         if len(word) < 3:
#             continue
#         else:
#             pass # Here you would write the code to count the
#                  # number of tiem words would appear and store
#                  # it in a dictionary.  pass just means we don't
#                  # have any code yet for the else block

# %%
# Place your solution to the subproblem here
uncommon_word_freq={}
for word in words:
    if len(word) < 3 or word not in remove_common_words:
        continue
    else:
        if word in uncommon_word_freq  : 
            uncommon_word_freq[word]=uncommon_word_freq[word]+1
        else:
            uncommon_word_freq[word]=1

# %% [markdown]
# ## Part 6: Generating the word cloud
#
# ### Overview
#
# Input: the dictionary of word and frequency key, value pairs.
#
# Output: the word cloud graphic
#
#
# ### Description
#
# At this point we're going to let a third-party handle rendering this graphic.  The only thing in the code below you need to change is the variable `CHANGE_ME` to be the dictionary output of Part 5.

# %%
wordcloud = WordCloud(width=1024,\
                      height=768,\
                      relative_scaling=0.5,\
                      normalize_plurals=True).generate_from_frequencies(uncommon_word_freq)

plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()
